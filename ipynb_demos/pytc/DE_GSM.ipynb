# %%
import sys
sys.path.insert(0,'/home/caldaz/module/pyGSM')
import numpy as np
from de_gsm import GSM
from pytc import PyTC
from pes import PES
from eigenvector_follow import eigenvector_follow
from psiw import *
from rhf_lot import RHF_LOT
from nifty import pvec1d,pmat2d,click,printcool
from molecule import Molecule
import manage_xyz
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline

# %%
##### => Job Data <= #####
charge=0
basis='6-31gs'
filepath1 = 'data/butadiene_ethene.xyz'
filepath2 = 'data/cyclohexene.xyz'

# %%
#### => PSIW Obj <= ######
printcool("Build resources")
resources = ls.ResourceList.build()
printcool('{}'.format(resources))

molecule1 = ls.Molecule.from_xyz_file(filepath1)
molecule2 = ls.Molecule.from_xyz_file(filepath2)

geom1 = geometry.Geometry.build(
    resources=resources,
    molecule=molecule1,
    basisname=basis,
    )
geom2 = geometry.Geometry.build(
    resources=resources,
    molecule=molecule2,
    basisname=basis,
    )

printcool('{}'.format(geom1))
printcool('{}'.format(geom2))

ref1 = RHF(RHF.default_options().set_values({
    'geometry' : geom1,
    'dft_functional' : 'B3LYP',
    'dft_grid_name' : 'SG0',
    }))
ref2 = RHF(RHF.default_options().set_values({
    'geometry' : geom2,
    'dft_functional' : 'B3LYP',
    'dft_grid_name' : 'SG0',
    }))

psiw1 = RHF_LOT.from_options(rhf=ref1)
psiw2 = RHF_LOT.from_options(rhf=ref2)
# Out:
# #========================================================#
# #|                   Build resources                    |#
# #========================================================#
# #==============================================================#
# #|                       ResourceList:                        |#
# #|                       CPU threads:   1                     |#
# #|                       GPU contexts:  1                     |#
# #|                     GPU context details:                   |#
# #|    N  ID                 Name  CC  CPU Buffer  GPU Buffer  |#
# #|    0   0    GeForce GTX TITAN 3.5        1024        1024  |#
# #|                                                            |#
# #==============================================================#
# #========================================================#
# #|                      Geometry:                       |#
# #|                      QMMM = False                    |#
# #|                      -D3  = False                    |#
# #|                      ECP  = False                    |#
# #|                                                      |#
# #|              Molecule: butadiene_ethene              |#
# #|               Natom        =          16             |#
# #|               Charge       =       0.000             |#
# #|               Multiplicity =       1.000             |#
# #|                                                      |#
# #|                    Basis: 6-31gs                     |#
# #|                    nao     =   110                   |#
# #|                    ncart   =   110                   |#
# #|                    nprim   =   130                   |#
# #|                    nshell  =    56                   |#
# #|                    natom   =    16                   |#
# #|                    pure?   =    No                   |#
# #|                    max L   =     2                   |#
# #|                                                      |#
# #|                 Basis: cc-pvdz-minao                 |#
# #|                    nao     =    40                   |#
# #|                    ncart   =    40                   |#
# #|                    nprim   =   172                   |#
# #|                    nshell  =    28                   |#
# #|                    natom   =    16                   |#
# #|                    pure?   =   Yes                   |#
# #|                    max L   =     1                   |#
# #|                                                      |#
# #========================================================#
# #========================================================#
# #|                      Geometry:                       |#
# #|                      QMMM = False                    |#
# #|                      -D3  = False                    |#
# #|                      ECP  = False                    |#
# #|                                                      |#
# #|                Molecule: cyclohexene                 |#
# #|               Natom        =          16             |#
# #|               Charge       =       0.000             |#
# #|               Multiplicity =       1.000             |#
# #|                                                      |#
# #|                    Basis: 6-31gs                     |#
# #|                    nao     =   110                   |#
# #|                    ncart   =   110                   |#
# #|                    nprim   =   130                   |#
# #|                    nshell  =    56                   |#
# #|                    natom   =    16                   |#
# #|                    pure?   =    No                   |#
# #|                    max L   =     2                   |#
# #|                                                      |#
# #|                 Basis: cc-pvdz-minao                 |#
# #|                    nao     =    40                   |#
# #|                    ncart   =    40                   |#
# #|                    nprim   =   172                   |#
# #|                    nshell  =    28                   |#
# #|                    natom   =    16                   |#
# #|                    pure?   =   Yes                   |#
# #|                    max L   =     1                   |#
# #|                                                      |#
# #========================================================#

# %%
####### =>  Build the pyGSM objects <= #########
# level of theory
printcool("Build the pyGSM Level of Theory object (LOT)")
lot1=PyTC.from_options(states=[(1,0)],psiw=psiw1,fnm=filepath1)
lot2=PyTC.from_options(states=[(1,0)],psiw=psiw2,fnm=filepath2)

# => Create PES objects <= #
printcool("Building the PES objects")
pes1 = PES.from_options(lot=lot1,ad_idx=0,multiplicity=1)
pes2 = PES.from_options(lot=lot2,ad_idx=0,multiplicity=1)

# => Molecule <= #
printcool("Build the pyGSM Molecule object \n with Translation and Rotation Internal Coordinates (TRIC)")
reactant = Molecule.from_options(fnm=filepath1,PES=pes1,coordinate_type="TRIC")
product = Molecule.from_options(fnm=filepath2,PES=pes2,coordinate_type="TRIC")

optimizer=eigenvector_follow.from_options(print_level=1)  #default parameters fine here/opt_type will get set by GSM
# Out:
# #========================================================#
# #|     Build the pyGSM Level of Theory object (LOT)     |#
# #========================================================#
#  initializing LOT from file
#  initializing LOT from file
# #========================================================#
# #|               Building the PES objects               |#
# #========================================================#
# #================================================================#
# #|               Build the pyGSM Molecule object                |#
# #|   with Translation and Rotation Internal Coordinates (TRIC)  |#
# #================================================================#
#  reading cartesian coordinates from file
#  making primitives from options!
# 39 10
# 21 6
# time to form B-matrix 0.014
# time to mat-mult B 0.000
# Build G: 0.014 Eig: 0.001
#  making primitive Hessian
#  forming Hessian in basis
#  reading cartesian coordinates from file
#  making primitives from options!
# 95 16
# time to form B-matrix 0.021
# time to mat-mult B 0.000
# Build G: 0.021 Eig: 0.002
#  making primitive Hessian
#  forming Hessian in basis

# %%
printcool("Primitives before union")
print(reactant.coord_obj.Prims.Internals)
# Out:
# #========================================================#
# #|               Primitives before union                |#
# #========================================================#
# [Distance 1-2, Distance 1-6, Distance 1-7, Distance 2-3, Distance 2-5, Distance 3-4, Distance 3-10, Distance 4-9, Distance 4-8, Angle 2-1-7, Angle 6-1-7, Angle 1-2-5, Angle 3-2-5, Angle 2-3-10, Angle 4-3-10, Angle 3-4-9, Angle 8-4-9, Out-of-Plane 1-2-6-7, Out-of-Plane 2-1-3-5, Out-of-Plane 3-2-4-10, Out-of-Plane 4-3-8-9, Dihedral 6-1-2-3, Dihedral 6-1-2-5, Dihedral 7-1-2-3, Dihedral 7-1-2-5, Dihedral 1-2-3-4, Dihedral 1-2-3-10, Dihedral 5-2-3-4, Dihedral 5-2-3-10, Dihedral 2-3-4-9, Dihedral 2-3-4-8, Dihedral 10-3-4-9, Dihedral 10-3-4-8, Translation-X 1-10, Translation-Y 1-10, Translation-Z 1-10, Rotation-A 1-10, Rotation-B 1-10, Rotation-C 1-10, Distance 11-12, Distance 11-13, Distance 11-14, Distance 12-15, Distance 12-16, Angle 12-11-14, Angle 13-11-14, Angle 11-12-16, Angle 15-12-16, Out-of-Plane 11-12-13-14, Out-of-Plane 12-11-15-16, Dihedral 13-11-12-15, Dihedral 13-11-12-16, Dihedral 14-11-12-15, Dihedral 14-11-12-16, Translation-X 11-16, Translation-Y 11-16, Translation-Z 11-16, Rotation-A 11-16, Rotation-B 11-16, Rotation-C 11-16]

# %%
printcool("Primitives before union")
print(product.coord_obj.Prims.Internals)
# Out:
# #========================================================#
# #|               Primitives before union                |#
# #========================================================#
# [Distance 1-2, Distance 1-11, Distance 1-6, Distance 1-7, Distance 2-3, Distance 2-5, Distance 3-4, Distance 3-10, Distance 4-9, Distance 4-12, Distance 4-8, Distance 11-12, Distance 11-13, Distance 11-14, Distance 12-15, Distance 12-16, Angle 2-1-11, Angle 2-1-6, Angle 2-1-7, Angle 6-1-11, Angle 6-1-7, Angle 7-1-11, Angle 1-2-5, Angle 3-2-5, Angle 2-3-10, Angle 4-3-10, Angle 9-4-12, Angle 3-4-9, Angle 3-4-12, Angle 3-4-8, Angle 8-4-9, Angle 8-4-12, Angle 1-11-12, Angle 1-11-13, Angle 1-11-14, Angle 12-11-13, Angle 12-11-14, Angle 13-11-14, Angle 11-12-15, Angle 11-12-16, Angle 4-12-11, Angle 4-12-15, Angle 4-12-16, Angle 15-12-16, Out-of-Plane 2-1-3-5, Out-of-Plane 3-2-4-10, Dihedral 11-1-2-3, Dihedral 11-1-2-5, Dihedral 6-1-2-3, Dihedral 6-1-2-5, Dihedral 7-1-2-3, Dihedral 7-1-2-5, Dihedral 2-1-11-12, Dihedral 2-1-11-13, Dihedral 2-1-11-14, Dihedral 6-1-11-12, Dihedral 6-1-11-13, Dihedral 6-1-11-14, Dihedral 7-1-11-12, Dihedral 7-1-11-13, Dihedral 7-1-11-14, Dihedral 1-2-3-4, Dihedral 1-2-3-10, Dihedral 5-2-3-4, Dihedral 5-2-3-10, Dihedral 2-3-4-9, Dihedral 2-3-4-12, Dihedral 2-3-4-8, Dihedral 10-3-4-9, Dihedral 10-3-4-12, Dihedral 10-3-4-8, Dihedral 9-4-12-11, Dihedral 9-4-12-15, Dihedral 9-4-12-16, Dihedral 3-4-12-11, Dihedral 3-4-12-15, Dihedral 3-4-12-16, Dihedral 8-4-12-11, Dihedral 8-4-12-15, Dihedral 8-4-12-16, Dihedral 1-11-12-4, Dihedral 1-11-12-15, Dihedral 1-11-12-16, Dihedral 13-11-12-4, Dihedral 13-11-12-15, Dihedral 13-11-12-16, Dihedral 14-11-12-4, Dihedral 14-11-12-15, Dihedral 14-11-12-16, Translation-X 1-16, Translation-Y 1-16, Translation-Z 1-16, Rotation-A 1-16, Rotation-B 1-16, Rotation-C 1-16]

# %%
printcool("Topology before union")
plt.plot()
nx.draw(reactant.coord_obj.Prims.topology,with_labels=True,font_weight='bold') 
plt.show()
# Out:
# #========================================================#
# #|                Topology before union                 |#
# #========================================================#

# %%
printcool("Topology before union")
plt.plot()
nx.draw(product.coord_obj.Prims.topology,with_labels=True,font_weight='bold') 
plt.show()
# Out:
# #========================================================#
# #|                Topology before union                 |#
# #========================================================#

# %%
printcool("Wilson B-Matrix (dq_i/dx_j) before union")
Bmatp = reactant.coord_obj.Prims.wilsonB(reactant.xyz)
plt.imshow(Bmatp, cmap=plt.cm.get_cmap('RdBu'))
plt.show()
# Out:
# #========================================================#
# #|       Wilson B-Matrix (dq_i/dx_j) before union       |#
# #========================================================#

# %%
printcool("Coordinate Basis before union")
plt.imshow(reactant.coord_basis, cmap=plt.cm.get_cmap('RdBu'))
plt.show()
# Out:
# #========================================================#
# #|            Coordinate Basis before union             |#
# #========================================================#

# %%
gsm = GSM.from_options(reactant=reactant,product=product,nnodes=9,optimizer=optimizer,print_level=1)
# Out:
#         __        __   _                            _
#         \ \      / /__| | ___ ___  _ __ ___   ___  | |_ ___
#          \ \ /\ / / _ \ |/ __/ _ \| '_ ` _ \ / _ \ | __/ _ \
#           \ V  V /  __/ | (_| (_) | | | | | |  __/ | || (_) |
#            \_/\_/ \___|_|\___\___/|_| |_| |_|\___|  \__\___/
#                                         ____ ____  __  __
#                            _ __  _   _ / ___/ ___||  \/  |
#                           | '_ \| | | | |  _\___ \| |\/| |
#                           | |_) | |_| | |_| |___) | |  | |
#                           | .__/ \__, |\____|____/|_|  |_|
#                           |_|    |___/
# #==========================================================================#
# #| If this code has benefited your research, please support us by citing: |#
# #|                                                                        |#
# #| Aldaz, C.; Kammeraad J. A.; Zimmerman P. M. "Discovery of conical      |#
# #| intersection mediated photochemistry with growing string methods",     |#
# #| Phys. Chem. Chem. Phys., 2018, 20, 27394                               |#
# #| http://dx.doi.org/10.1039/c8cp04703k                                   |#
# #|                                                                        |#
# #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
# #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
# #| http://dx.doi.org/10.1063/1.4952956                                    |#
# #==========================================================================#
#
#
#
#  gaddmax: 0.0154303349962
#  making primitive Hessian
#  Forming Union of primitive coordinates
# ('Adding ', Distance 1-11)
# ('Adding ', Distance 4-12)
# ('Adding ', Angle 2-1-11)
# ('Adding ', Angle 2-1-6)
# ('Adding ', Angle 6-1-11)
# ('Adding ', Angle 7-1-11)
# ('Adding ', Angle 9-4-12)
# ('Adding ', Angle 3-4-12)
# ('Adding ', Angle 3-4-8)
# ('Adding ', Angle 8-4-12)
# ('Adding ', Angle 1-11-12)
# ('Adding ', Angle 1-11-13)
# ('Adding ', Angle 1-11-14)
# ('Adding ', Angle 12-11-13)
# ('Adding ', Angle 11-12-15)
# ('Adding ', Angle 4-12-11)
# ('Adding ', Angle 4-12-15)
# ('Adding ', Angle 4-12-16)
# ('Adding ', Dihedral 11-1-2-3)
# ('Adding ', Dihedral 11-1-2-5)
# ('Adding ', Dihedral 2-1-11-12)
# ('Adding ', Dihedral 2-1-11-13)
# ('Adding ', Dihedral 2-1-11-14)
# ('Adding ', Dihedral 6-1-11-12)
# ('Adding ', Dihedral 6-1-11-13)
# ('Adding ', Dihedral 6-1-11-14)
# ('Adding ', Dihedral 7-1-11-12)
# ('Adding ', Dihedral 7-1-11-13)
# ('Adding ', Dihedral 7-1-11-14)
# ('Adding ', Dihedral 2-3-4-12)
# ('Adding ', Dihedral 10-3-4-12)
# ('Adding ', Dihedral 9-4-12-11)
# ('Adding ', Dihedral 9-4-12-15)
# ('Adding ', Dihedral 9-4-12-16)
# ('Adding ', Dihedral 3-4-12-11)
# ('Adding ', Dihedral 3-4-12-15)
# ('Adding ', Dihedral 3-4-12-16)
# ('Adding ', Dihedral 8-4-12-11)
# ('Adding ', Dihedral 8-4-12-15)
# ('Adding ', Dihedral 8-4-12-16)
# ('Adding ', Dihedral 1-11-12-4)
# ('Adding ', Dihedral 1-11-12-15)
# ('Adding ', Dihedral 1-11-12-16)
# ('Adding ', Dihedral 13-11-12-4)
# ('Adding ', Dihedral 14-11-12-4)
# ('Adding ', Translation-X 1-16)
# ('Adding ', Translation-Y 1-16)
# ('Adding ', Translation-Z 1-16)
# ('Adding ', Rotation-A 1-16)
# ('Adding ', Rotation-B 1-16)
# ('Adding ', Rotation-C 1-16)
#  setting primitives from options!
# 111 16
# time to form B-matrix 0.024
# time to mat-mult B 0.000
# Build G: 0.024 Eig: 0.003
#  making primitive Hessian
#  Done forming union
#  setting primitives from options!
# 111 16
# time to form B-matrix 0.028
# time to mat-mult B 0.000
# Build G: 0.028 Eig: 0.002
#  making primitive Hessian
#  Primitive Internal Coordinates
# [Distance 1-2, Distance 1-6, Distance 1-7, Distance 2-3, Distance 2-5, Distance 3-4, Distance 3-10, Distance 4-9, Distance 4-8, Distance 11-12, Distance 11-13, Distance 11-14, Distance 12-15, Distance 12-16, Distance 1-11, Distance 4-12, Angle 2-1-7, Angle 6-1-7, Angle 1-2-5, Angle 3-2-5, Angle 2-3-10, Angle 4-3-10, Angle 3-4-9, Angle 8-4-9, Angle 12-11-14, Angle 13-11-14, Angle 11-12-16, Angle 15-12-16, Angle 2-1-11, Angle 2-1-6, Angle 6-1-11, Angle 7-1-11, Angle 9-4-12, Angle 3-4-12, Angle 3-4-8, Angle 8-4-12, Angle 1-11-12, Angle 1-11-13, Angle 1-11-14, Angle 12-11-13, Angle 11-12-15, Angle 4-12-11, Angle 4-12-15, Angle 4-12-16, Out-of-Plane 1-2-6-7, Out-of-Plane 2-1-3-5, Out-of-Plane 3-2-4-10, Out-of-Plane 4-3-8-9, Out-of-Plane 11-12-13-14, Out-of-Plane 12-11-15-16, Dihedral 6-1-2-3, Dihedral 6-1-2-5, Dihedral 7-1-2-3, Dihedral 7-1-2-5, Dihedral 1-2-3-4, Dihedral 1-2-3-10, Dihedral 5-2-3-4, Dihedral 5-2-3-10, Dihedral 2-3-4-9, Dihedral 2-3-4-8, Dihedral 10-3-4-9, Dihedral 10-3-4-8, Dihedral 13-11-12-15, Dihedral 13-11-12-16, Dihedral 14-11-12-15, Dihedral 14-11-12-16, Dihedral 11-1-2-3, Dihedral 11-1-2-5, Dihedral 2-1-11-12, Dihedral 2-1-11-13, Dihedral 2-1-11-14, Dihedral 6-1-11-12, Dihedral 6-1-11-13, Dihedral 6-1-11-14, Dihedral 7-1-11-12, Dihedral 7-1-11-13, Dihedral 7-1-11-14, Dihedral 2-3-4-12, Dihedral 10-3-4-12, Dihedral 9-4-12-11, Dihedral 9-4-12-15, Dihedral 9-4-12-16, Dihedral 3-4-12-11, Dihedral 3-4-12-15, Dihedral 3-4-12-16, Dihedral 8-4-12-11, Dihedral 8-4-12-15, Dihedral 8-4-12-16, Dihedral 1-11-12-4, Dihedral 1-11-12-15, Dihedral 1-11-12-16, Dihedral 13-11-12-4, Dihedral 14-11-12-4, Translation-X 1-10, Translation-X 11-16, Translation-X 1-16, Translation-Y 1-10, Translation-Y 11-16, Translation-Y 1-16, Translation-Z 1-10, Translation-Z 11-16, Translation-Z 1-16, Rotation-A 1-10, Rotation-A 11-16, Rotation-A 1-16, Rotation-B 1-10, Rotation-B 11-16, Rotation-B 1-16, Rotation-C 1-10, Rotation-C 11-16, Rotation-C 1-16]
#  number of primitives is 111

# %%
printcool("Topology after union")
plt.plot()
nx.draw(gsm.nodes[0].coord_obj.Prims.topology,with_labels=True,font_weight='bold') 
plt.show()
# Out:
# #========================================================#
# #|                 Topology after union                 |#
# #========================================================#

# %%
printcool("Wilson B-Matrix (dq_i/dx_j)")
Bmatp = gsm.nodes[0].coord_obj.Prims.wilsonB(reactant.xyz)
plt.imshow(Bmatp, cmap=plt.cm.get_cmap('RdBu'))
plt.show()
# Out:
# #========================================================#
# #|             Wilson B-Matrix (dq_i/dx_j)              |#
# #========================================================#

# %%
printcool("Coordinate Basis")
plt.imshow(gsm.nodes[0].coord_basis, cmap=plt.cm.get_cmap('RdBu'))
plt.show()
# Out:
# #========================================================#
# #|                   Coordinate Basis                   |#
# #========================================================#
