# %%
import sys
sys.path.insert(0,'/home/caldaz/module/pyGSM')
from molecule import Molecule
from pes import PES
from avg_pes import Avg_PES
import numpy as np
from nifty import pvec1d,pmat2d
import matplotlib
import matplotlib.pyplot as plt
from pytc import *
import manage_xyz
from rhf_lot import *
from psiw import *
from nifty import getAllCoords,getAtomicSymbols,click,printcool
import pybel as pb
# %matplotlib inline

# %%
printcool("Build resources")
resources = ls.ResourceList.build()
printcool('{}'.format(resources))
# Out:
# #========================================================#
# #|                   Build resources                    |#
# #========================================================#
# #==============================================================#
# #|                       ResourceList:                        |#
# #|                       CPU threads:   1                     |#
# #|                       GPU contexts:  1                     |#
# #|                     GPU context details:                   |#
# #|    N  ID                 Name  CC  CPU Buffer  GPU Buffer  |#
# #|    0   0    GeForce GTX TITAN 3.5        1024        1024  |#
# #|                                                            |#
# #==============================================================#
# '----------------------------------------------------------------\n'

# %%
printcool("build the Lightspeed (pyTC) objecs")

filepath='../data/twisted_fluoroethene.xyz'
nocc=11

molecule = ls.Molecule.from_xyz_file(filepath)
geom = geometry.Geometry.build(
    resources=resources,
    molecule=molecule,
    basisname='6-31gs',
    )
printcool('{}'.format(geom))

ref = RHF.from_options(
     geometry= geom, 
     g_convergence=1.0E-6,
     fomo=True,
     fomo_method='gaussian',
     fomo_temp=0.3,
     fomo_nocc=nocc,
     fomo_nact=2,
     print_level=1,
    )
ref.compute_energy()
casci = CASCI.from_options(
    reference=ref,
    nocc=nocc,
    nact=2,
    nalpha=1,
    nbeta=1,
    S_inds=[0],
    S_nstates=[2],
    print_level=1,
    )
casci.compute_energy()
psiw = CASCI_LOT.from_options(
    casci=casci,
    rhf_guess=True,
    rhf_mom=True,
    orbital_coincidence='core',
    state_coincidence='full',
    )
# Out:
# #========================================================#
# #|          build the Lightspeed (pyTC) objecs          |#
# #========================================================#
# #========================================================#
# #|                      Geometry:                       |#
# #|                      QMMM = False                    |#
# #|                      -D3  = False                    |#
# #|                      ECP  = False                    |#
# #|                                                      |#
# #|            Molecule: twisted_fluoroethene            |#
# #|               Natom        =           6             |#
# #|               Charge       =       0.000             |#
# #|               Multiplicity =       1.000             |#
# #|                                                      |#
# #|                    Basis: 6-31gs                     |#
# #|                    nao     =    51                   |#
# #|                    ncart   =    51                   |#
# #|                    nprim   =    57                   |#
# #|                    nshell  =    24                   |#
# #|                    natom   =     6                   |#
# #|                    pure?   =    No                   |#
# #|                    max L   =     2                   |#
# #|                                                      |#
# #|                 Basis: cc-pvdz-minao                 |#
# #|                    nao     =    18                   |#
# #|                    ncart   =    18                   |#
# #|                    nprim   =    78                   |#
# #|                    nshell  =    12                   |#
# #|                    natom   =     6                   |#
# #|                    pure?   =   Yes                   |#
# #|                    max L   =     1                   |#
# #|                                                      |#
# #========================================================#
# ==> RHF <==
#
# External Environment:
#   Enuc =   6.8246411458977590E+01
#   Eext =   6.8246411458977590E+01
#
# SCF Iterations:
#
# Iter:                   Energy          dE          dG  Time[s]
#    0:  -1.7599180090279924E+02  -1.760E+02   1.245E+00    0.887
#    1:  -1.7690319850470294E+02  -9.114E-01   3.516E-02    0.070
#    2:  -1.7693984696942849E+02  -3.665E-02   1.845E-02    0.065
#    3:  -1.7694805805048333E+02  -8.211E-03   5.416E-03    0.062
#    4:  -1.7694885438088744E+02  -7.963E-04   1.160E-03    0.060
#    5:  -1.7694890470337140E+02  -5.032E-05   3.934E-04    0.055
#    6:  -1.7694891064690168E+02  -5.944E-06   1.160E-04    0.052
#    7:  -1.7694891137207946E+02  -7.252E-07   4.130E-05    0.050
#    8:  -1.7694891145963828E+02  -8.756E-08   8.695E-06    0.062
#    9:  -1.7694891146544279E+02  -5.805E-09   2.101E-06    0.046
#   10:  -1.7694891146574309E+02  -3.003E-10   6.545E-07    0.042
#
# SCF Converged
#
# SCF Energy =  -1.7694891146574309E+02
#
# SCF Internal Energy (E)     =  -1.7649324353178383E+02
# SCF Entropy Term (-T * S)   =  -4.5566793395925259E-01
# SCF Free Energy (E - T * S) =  -1.7694891146574309E+02
#
# ==> End RHF <==
#
# ==> CASCI <==
#
# External Environment:
#   Enuc =   6.8246411458977590E+01
#   Eext =   6.8246411458977590E+01
#
# Core Energy =  -175.66516750321773
#
# => S=0 States <=
#
# CASCI S=0 Energies:
#
#    I:                  Total E
#    0:  -1.7674088210471800E+02
#    1:  -1.7656769612747098E+02
#
# => End S=0 States <=
#
# ==> End CASCI <==

# %%
printcool("Build the pyGSM Level of Theory object (LOT)")
lot=PyTC.from_options(states=[(1,0),(1,1)],extra_kwargs={'psiw':psiw},fnm=filepath)
# Out:
# #========================================================#
# #|     Build the pyGSM Level of Theory object (LOT)     |#
# #========================================================#
#  initializing LOT from file

# %%
printcool("Build the pyGSM Potential Energy Surface Object (PES)")
pes = PES.from_options(lot=lot,ad_idx=0,multiplicity=1)
# Out:
# #===========================================================#
# #|  Build the pyGSM Potential Energy Surface Object (PES)  |#
# #===========================================================#

# %%
printcool("Build the pyGSM Molecule object \n with Translation and Rotation Internal Coordinates (TRIC)")
M = Molecule.from_options(fnm=filepath,PES=pes,coordinate_type="Cartesian")
# Out:
# #================================================================#
# #|               Build the pyGSM Molecule object                |#
# #|   with Translation and Rotation Internal Coordinates (TRIC)  |#
# #================================================================#
#  reading cartesian coordinates from file
#  initializing LOT from file

# %%
from conjugate_gradient import conjugate_gradient
from _linesearch import backtrack
cg = conjugate_gradient.from_options(Linesearch=backtrack,DMAX=0.25)
#cg = conjugate_gradient.from_options(DMAX=0.1)

# %%
geoms,energy = cg.optimize(M,M.energy,'UNCONSTRAINED',30)
# Out:
#  initial E 0.0000
#  On opt step 1
# [[-0.108   0.0295 -0.0303 -0.1933  0.0597 -0.4973  0.0117 -0.0946  0.0063
#   -0.0257  0.057   0.0006  0.3197  0.0222  0.5918 -0.0044 -0.0738 -0.0711]]
#  actual_step= 0.88
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-27.9384
#  Opt step: 1 E: -27.9384 gradrms: 0.20792 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.09 (au)
#  maximum gradient component 0.07 (au)
#
#  On opt step 2
#  beta = 0.20
# [[-0.1212  0.0234 -0.0703  0.1452  0.0024  0.1469  0.0059 -0.0945  0.0316
#   -0.0668  0.0501 -0.013  -0.0118  0.0499  0.0575  0.0487 -0.0314 -0.1526]]
#  actual_step= 0.34
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-16.8680
#  Opt step: 2 E: -44.8065 gradrms: 0.09230 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.06 (au)
#  maximum gradient component 0.06 (au)
#
#  On opt step 3
#  beta = 0.89
# [[ 0.1859  0.0903 -0.0421  0.0197  0.0395  0.1045 -0.0543 -0.112   0.0886
#   -0.1519  0.0051 -0.0865 -0.0221  0.076   0.0685  0.0228 -0.099  -0.1329]]
#  actual_step= 0.39
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-11.7380
#  Opt step: 3 E: -56.5444 gradrms: 0.08692 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.06 (au)
#  maximum gradient component 0.09 (au)
#
#  On opt step 4
#  beta = 0.63
# [[ 0.0723  0.0198 -0.008  -0.0266  0.0836 -0.1108 -0.007  -0.1308  0.0324
#   -0.0134  0.0975 -0.0157  0.0023  0.0881  0.0981 -0.0277 -0.1582  0.0039]]
#  actual_step= 0.31
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-8.3970
#  Opt step: 4 E: -64.9415 gradrms: 0.06883 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.04 (au)
#  maximum gradient component 0.12 (au)
#
#  On opt step 5
#  beta = 1.58
# [[-0.111  -0.0281 -0.0118  0.0469  0.1519 -0.0289  0.0511 -0.2528  0.0211
#    0.0841  0.2495  0.007  -0.0488  0.1741  0.0291 -0.0223 -0.2945 -0.0164]]
#  actual_step= 0.54
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-13.2342
#  Opt step: 5 E: -78.1757 gradrms: 0.08654 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.06 (au)
#  maximum gradient component 0.07 (au)
#
#  On opt step 6
#  beta = 0.78
# [[-0.0105 -0.0205  0.0311 -0.0942  0.102   0.1834  0.048  -0.2121  0.0367
#    0.0834  0.2168 -0.0389 -0.0791  0.165  -0.1178  0.0524 -0.2512 -0.0945]]
#  actual_step= 0.53
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-9.1628
#  Opt step: 6 E: -87.3385 gradrms: 0.07636 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.05 (au)
#  maximum gradient component 0.07 (au)
#
#  On opt step 7
#  beta = 0.78
# [[ 0.1334  0.0157  0.1167 -0.085   0.0279  0.0065 -0.0163 -0.1627  0.092
#    0.0298  0.1537 -0.1307 -0.0634  0.1515 -0.1097  0.0014 -0.1861  0.0251]]
#  actual_step= 0.44
#  reducing step, new step = 0.25
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.12
#  Done linesearch
#  dEstep=-3.6986
#  Opt step: 7 E: -91.0371 gradrms: 0.06723 ss: 0.125 DMAX: 0.125
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.08 (au)
#
#  On opt step 8
#  beta = 0.77
# [[ 0.0331 -0.0042  0.0931  0.0514 -0.025  -0.142  -0.0465 -0.1212  0.1179
#    0.0456  0.1312 -0.1248 -0.0309  0.1383 -0.0672 -0.0527 -0.1191  0.1231]]
#  actual_step= 0.39
#  reducing step, new step = 0.12
#  Linesearch
#  Done linesearch
#  dEstep=-5.6878
#  Opt step: 8 E: -96.7248 gradrms: 0.05890 ss: 0.125 DMAX: 0.125
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.06 (au)
#
#  On opt step 9
#  beta = 0.43
# [[-0.0964 -0.03   -0.0122  0.0879 -0.037  -0.0796 -0.0148 -0.0438  0.0601
#    0.0575  0.0709 -0.0254  0.0089  0.0693 -0.0325 -0.0431 -0.0293  0.0896]]
#  actual_step= 0.24
#  reducing step, new step = 0.12
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.06
#  Done linesearch
#  dEstep=-0.8956
#  Opt step: 9 E: -97.6204 gradrms: 0.03846 ss: 0.062 DMAX: 0.062
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.05 (au)
#
#  On opt step 10
#  beta = 0.57
# [[-0.0303 -0.0247 -0.0329 -0.0364 -0.0341  0.0168  0.0007 -0.0174  0.0275
#    0.0406  0.0442 -0.0038  0.0278  0.0431 -0.0317 -0.0023 -0.0111  0.024 ]]
#  actual_step= 0.12
#  reducing step, new step = 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-0.2986
#  Opt step: 10 E: -97.9190 gradrms: 0.02898 ss: 0.062 DMAX: 0.062
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 11
#  beta = 1.16
# [[ 0.0221 -0.0166  0.0221 -0.105  -0.0489  0.0591  0.0116 -0.0157 -0.0039
#    0.0139  0.0387 -0.0369  0.0441  0.0481 -0.043   0.0134 -0.0056  0.0024]]
#  actual_step= 0.17
#  reducing step, new step = 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-0.0430
#  Opt step: 11 E: -97.9621 gradrms: 0.03119 ss: 0.062 DMAX: 0.062
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 12
#  beta = 1.04
# [[-0.0382 -0.0197  0.0575 -0.0059 -0.0532  0.0469  0.0113 -0.0092 -0.03
#   -0.0037  0.0283 -0.0486  0.0453  0.0423 -0.0422 -0.0088  0.0115  0.0165]]
#  actual_step= 0.14
#  reducing step, new step = 0.06
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.03
#  Done linesearch
#  dEstep=-0.1747
#  Opt step: 12 E: -98.1368 gradrms: 0.03177 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 13
#  beta = 0.68
# [[-0.0618 -0.0185  0.0319  0.0861 -0.0375  0.0036 -0.0129  0.0033 -0.0196
#   -0.0118  0.0089 -0.0263  0.0321  0.0207 -0.0164 -0.0318  0.0232  0.0267]]
#  actual_step= 0.14
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.3757
#  Opt step: 13 E: -98.5125 gradrms: 0.02624 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 14
#  beta = 0.54
# [[ 0.0199 -0.0102 -0.0142  0.0344 -0.0223 -0.012  -0.0399  0.0119  0.0089
#   -0.0153 -0.0047 -0.0017  0.0253  0.0047  0.0106 -0.0244  0.0205  0.0084]]
#  actual_step= 0.08
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.2885
#  Opt step: 14 E: -98.8010 gradrms: 0.01930 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 15
#  beta = 0.88
# [[ 0.0538 -0.0051 -0.0194 -0.0133 -0.011   0.0154 -0.0419  0.0163 -0.0016
#   -0.0164 -0.013   0.0133  0.0256 -0.0066  0.0167 -0.0077  0.0193 -0.0244]]
#  actual_step= 0.09
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.1982
#  Opt step: 15 E: -98.9992 gradrms: 0.01808 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 16
#  beta = 0.92
# [[ 0.0048 -0.0014 -0.0012  0.0061  0.0034  0.0318 -0.0222  0.0173 -0.0343
#   -0.0075 -0.0202  0.0287  0.02   -0.0199  0.0147 -0.0013  0.0208 -0.0396]]
#  actual_step= 0.09
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.3430
#  Opt step: 16 E: -99.3422 gradrms: 0.01735 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 17
#  beta = 0.81
# [[-0.0359  0.0048  0.0221  0.03    0.0087  0.007  -0.0041  0.0152 -0.0517
#    0.0023 -0.0246  0.03    0.0148 -0.0263  0.0166 -0.0072  0.0221 -0.024 ]]
#  actual_step= 0.10
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.2511
#  Opt step: 17 E: -99.5933 gradrms: 0.01560 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 18
#  beta = 0.64
# [[ 0.0087  0.0108  0.0171 -0.0058  0.0047 -0.0206 -0.0089  0.0134 -0.0251
#    0.004  -0.0238  0.0154  0.0118 -0.0234  0.0169 -0.0098  0.0183 -0.0037]]
#  actual_step= 0.06
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.0621
#  Opt step: 18 E: -99.6554 gradrms: 0.01249 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 19
#  beta = 0.98
# [[ 0.025   0.0102 -0.0124 -0.0105  0.0123 -0.0056 -0.0204  0.0187  0.0033
#    0.0111 -0.0281  0.0142  0.0052 -0.0319  0.0029 -0.0104  0.0188 -0.0023]]
#  actual_step= 0.07
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.0602
#  Opt step: 19 E: -99.7155 gradrms: 0.01239 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 20
#  beta = 1.28
# [[-0.0062  0.0117 -0.0198  0.0176  0.0247  0.0139 -0.0177  0.025   0.0101
#    0.0208 -0.0382  0.0124 -0.0022 -0.0464 -0.0128 -0.0124  0.0231 -0.0037]]
#  actual_step= 0.09
#  reducing step, new step = 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.0378
#  Opt step: 20 E: -99.7533 gradrms: 0.01403 ss: 0.031 DMAX: 0.031
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 21
#  beta = 0.54
# [[-0.0191  0.0118  0.0181  0.0055  0.0112  0.0045  0.0074  0.0104 -0.0044
#    0.0083 -0.0224 -0.0115  0.0004 -0.0216 -0.0049 -0.0026  0.0106 -0.0017]]
#  actual_step= 0.05
#  reducing step, new step = 0.03
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.02
#  Done linesearch
#  dEstep=-0.0801
#  Opt step: 21 E: -99.8334 gradrms: 0.01029 ss: 0.016 DMAX: 0.016
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 22
#  beta = 0.61
# [[-0.0042  0.0094  0.0209 -0.0198  0.0009 -0.0064  0.0119  0.0044 -0.0016
#    0.004  -0.0123 -0.018   0.0061 -0.0068  0.0054  0.0019  0.0043 -0.0002]]
#  actual_step= 0.04
#  reducing step, new step = 0.02
#  Linesearch
#  Done linesearch
#  dEstep=-0.0262
#  Opt step: 22 E: -99.8596 gradrms: 0.00803 ss: 0.016 DMAX: 0.016
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 23
#  beta = 0.74
# [[-0.0078  0.0003 -0.0061 -0.0127 -0.0014 -0.002   0.0068  0.0031  0.0124
#    0.0084 -0.0028 -0.0095  0.0045  0.0001  0.0031  0.0007  0.0007  0.0021]]
#  actual_step= 0.03
#  reducing step, new step = 0.02
#  Linesearch
#  Done linesearch
#  dEstep=-0.0097
#  Opt step: 23 E: -99.8692 gradrms: 0.00690 ss: 0.016 DMAX: 0.016
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 24
#  beta = 1.01
# [[-0.0138 -0.0046 -0.0161  0.0068 -0.0011  0.0059  0.0051  0.0012  0.017
#    0.0079  0.0031 -0.0065 -0.0033  0.0032 -0.006  -0.0027 -0.0018  0.0056]]
#  actual_step= 0.03
#  reducing step, new step = 0.02
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.01
#  Done linesearch
#  dEstep=-0.0367
#  Opt step: 24 E: -99.9059 gradrms: 0.00693 ss: 0.008 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.00 (au)
#
#  On opt step 25
#  beta = 0.33
# [[ 0.0044 -0.0021 -0.0007  0.007  -0.0019  0.0043  0.0013 -0.0027  0.0031
#   -0.003   0.0051 -0.0037 -0.007   0.0047 -0.0071 -0.0027 -0.003   0.0042]]
#  actual_step= 0.02
#  reducing step, new step = 0.01
#  Linesearch
#  Done linesearch
#  dEstep=-0.0331
#  Opt step: 25 E: -99.9390 gradrms: 0.00400 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.00 (au)
#
#  On opt step 26
#  beta = 1.24
# [[ 0.0127 -0.0028  0.0052 -0.0002 -0.0058 -0.0009  0.0037 -0.0065 -0.0022
#   -0.0065  0.0104 -0.003  -0.0077  0.0107 -0.0037 -0.0019 -0.0061  0.0046]]
#  actual_step= 0.03
#  reducing step, new step = 0.01
#  Linesearch
#  Done linesearch
#  dEstep=-0.0254
#  Opt step: 26 E: -99.9644 gradrms: 0.00445 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 27
#  beta = 0.92
# [[ 0.0018 -0.0054  0.002  -0.001  -0.0066 -0.0044  0.0062 -0.0084 -0.0062
#   -0.0036  0.0144  0.0043 -0.0046  0.0142  0.003   0.0013 -0.0081  0.0012]]
#  actual_step= 0.03
#  reducing step, new step = 0.01
#  Linesearch
#  Done linesearch
#  dEstep=-0.0380
#  Opt step: 27 E: -100.0024 gradrms: 0.00426 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 28
#  beta = 0.77
# [[-0.0081 -0.0071 -0.0052  0.002  -0.0043 -0.0008  0.0048 -0.0076 -0.0038
#   -0.0007  0.0143  0.0085 -0.0026  0.0132  0.0049  0.0047 -0.0085 -0.0035]]
#  actual_step= 0.03
#  reducing step, new step = 0.01
#  Linesearch
#  Done linesearch
#  dEstep=-0.0262
#  Opt step: 28 E: -100.0286 gradrms: 0.00375 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.00 (au)
#
#  On opt step 29
#  beta = 0.44
# [[ 0.0029 -0.0025 -0.0026 -0.0019 -0.001   0.0016 -0.001  -0.0038  0.0021
#   -0.0033  0.0062  0.001  -0.0016  0.0064  0.002   0.005  -0.0053 -0.0041]]
#  actual_step= 0.01
#  reducing step, new step = 0.01
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.01
#  [INFO] the linesearch step is too small
#  Done linesearch
#  dEstep=0.0040
#  Opt step: 29 E: -100.0246 gradrms: 0.00250 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.00 (au)
#
#  On opt step 30
#  beta = 2.05
# [[ 0.002  -0.0035  0.0011  0.0056 -0.0012 -0.0012 -0.0017 -0.0083  0.0035
#   -0.0094  0.0114 -0.0021 -0.0049  0.0122  0.0024  0.0085 -0.0106 -0.0037]]
#  actual_step= 0.03
#  reducing step, new step = 0.01
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.01
#  [INFO] the linesearch step is too small
#  Done linesearch
#  dEstep=0.0064
#  Opt step: 30 E: -100.0182 gradrms: 0.00358 ss: 0.010 DMAX: 0.010
#  maximum displacement component 0.00 (au)
#  maximum gradient component 0.00 (au)
#
#  opt-summary
#  Opt step: 1 E: -27.9384 gradrms: 0.20792 ss: 0.250 DMAX: 0.250
#  Opt step: 2 E: -44.8065 gradrms: 0.09230 ss: 0.250 DMAX: 0.250
#  Opt step: 3 E: -56.5444 gradrms: 0.08692 ss: 0.250 DMAX: 0.250
#  Opt step: 4 E: -64.9415 gradrms: 0.06883 ss: 0.250 DMAX: 0.250
#  Opt step: 5 E: -78.1757 gradrms: 0.08654 ss: 0.250 DMAX: 0.250
#  Opt step: 6 E: -87.3385 gradrms: 0.07636 ss: 0.250 DMAX: 0.250
#  Opt step: 7 E: -91.0371 gradrms: 0.06723 ss: 0.125 DMAX: 0.125
#  Opt step: 8 E: -96.7248 gradrms: 0.05890 ss: 0.125 DMAX: 0.125
#  Opt step: 9 E: -97.6204 gradrms: 0.03846 ss: 0.062 DMAX: 0.062
#  Opt step: 10 E: -97.9190 gradrms: 0.02898 ss: 0.062 DMAX: 0.062
#  Opt step: 11 E: -97.9621 gradrms: 0.03119 ss: 0.062 DMAX: 0.062
#  Opt step: 12 E: -98.1368 gradrms: 0.03177 ss: 0.031 DMAX: 0.031
#  Opt step: 13 E: -98.5125 gradrms: 0.02624 ss: 0.031 DMAX: 0.031
#  Opt step: 14 E: -98.8010 gradrms: 0.01930 ss: 0.031 DMAX: 0.031
#  Opt step: 15 E: -98.9992 gradrms: 0.01808 ss: 0.031 DMAX: 0.031
#  Opt step: 16 E: -99.3422 gradrms: 0.01735 ss: 0.031 DMAX: 0.031
#  Opt step: 17 E: -99.5933 gradrms: 0.01560 ss: 0.031 DMAX: 0.031
#  Opt step: 18 E: -99.6554 gradrms: 0.01249 ss: 0.031 DMAX: 0.031
#  Opt step: 19 E: -99.7155 gradrms: 0.01239 ss: 0.031 DMAX: 0.031
#  Opt step: 20 E: -99.7533 gradrms: 0.01403 ss: 0.031 DMAX: 0.031
#  Opt step: 21 E: -99.8334 gradrms: 0.01029 ss: 0.016 DMAX: 0.016
#  Opt step: 22 E: -99.8596 gradrms: 0.00803 ss: 0.016 DMAX: 0.016
#  Opt step: 23 E: -99.8692 gradrms: 0.00690 ss: 0.016 DMAX: 0.016
#  Opt step: 24 E: -99.9059 gradrms: 0.00693 ss: 0.008 DMAX: 0.010
#  Opt step: 25 E: -99.9390 gradrms: 0.00400 ss: 0.010 DMAX: 0.010
#  Opt step: 26 E: -99.9644 gradrms: 0.00445 ss: 0.010 DMAX: 0.010
#  Opt step: 27 E: -100.0024 gradrms: 0.00426 ss: 0.010 DMAX: 0.010
#  Opt step: 28 E: -100.0286 gradrms: 0.00375 ss: 0.010 DMAX: 0.010
#  Opt step: 29 E: -100.0246 gradrms: 0.00250 ss: 0.010 DMAX: 0.010
#  Opt step: 30 E: -100.0182 gradrms: 0.00358 ss: 0.010 DMAX: 0.010

# %%
manage_xyz.write_xyzs_w_comments('cartesian_sd.xyz',geoms,energy,scale=1.)

# %%
printcool("Build the pyGSM Molecule object \n with Translation and Rotation Internal Coordinates (TRIC)")
newM = Molecule.from_options(geom = geoms[-1],PES=pes,coordinate_type="TRIC")
# Out:
# #================================================================#
# #|               Build the pyGSM Molecule object                |#
# #|   with Translation and Rotation Internal Coordinates (TRIC)  |#
# #================================================================#
#  getting cartesian coordinates from geom
#  initializing LOT from file
#  making primitives from options!
#  making primitive Hessian
#  forming Hessian in basis

# %%
newM.gradient
# Out:
# array([[-0.    ],
#        [-0.    ],
#        [ 0.    ],
#        [-0.    ],
#        [ 0.    ],
#        [ 0.0007],
#        [-0.    ],
#        [ 0.0002],
#        [-0.0041],
#        [-0.0041],
#        [ 0.0057],
#        [-0.0005],
#        [-0.0031],
#        [ 0.0006],
#        [ 0.0033],
#        [ 0.0016],
#        [-0.001 ],
#        [-0.    ]])

# %%
np.sqrt(np.dot(newM.gradient.T,newM.gradient)/newM.num_coordinates)
# Out:
# array([[ 0.0022]])
