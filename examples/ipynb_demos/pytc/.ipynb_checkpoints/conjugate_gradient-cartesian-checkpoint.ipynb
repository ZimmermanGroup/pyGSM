# %%
import sys
sys.path.insert(0,'/home/caldaz/module/pyGSM')
from molecule import Molecule
from pes import PES
from avg_pes import Avg_PES
import numpy as np
from nifty import pvec1d,pmat2d
import matplotlib
import matplotlib.pyplot as plt
from pytc import *
import manage_xyz
from rhf_lot import *
from psiw import *
from nifty import getAllCoords,getAtomicSymbols,click,printcool
import pybel as pb
# %matplotlib inline

# %%
printcool("Build resources")
resources = ls.ResourceList.build()
printcool('{}'.format(resources))
# Out:
# #========================================================#
# #|                   Build resources                    |#
# #========================================================#
# #==============================================================#
# #|                       ResourceList:                        |#
# #|                       CPU threads:   1                     |#
# #|                       GPU contexts:  1                     |#
# #|                     GPU context details:                   |#
# #|    N  ID                 Name  CC  CPU Buffer  GPU Buffer  |#
# #|    0   0    GeForce GTX TITAN 3.5        1024        1024  |#
# #|                                                            |#
# #==============================================================#
# '----------------------------------------------------------------\n'

# %%
printcool("build the Lightspeed (pyTC) objecs")

filepath='../data/twisted_fluoroethene.xyz'
nocc=11

molecule = ls.Molecule.from_xyz_file(filepath)
geom = geometry.Geometry.build(
    resources=resources,
    molecule=molecule,
    basisname='6-31gs',
    )
printcool('{}'.format(geom))

ref = RHF.from_options(
     geometry= geom, 
     g_convergence=1.0E-6,
     fomo=True,
     fomo_method='gaussian',
     fomo_temp=0.3,
     fomo_nocc=nocc,
     fomo_nact=2,
     print_level=1,
    )
ref.compute_energy()
casci = CASCI.from_options(
    reference=ref,
    nocc=nocc,
    nact=2,
    nalpha=1,
    nbeta=1,
    S_inds=[0],
    S_nstates=[2],
    print_level=1,
    )
casci.compute_energy()
psiw = CASCI_LOT.from_options(
    casci=casci,
    rhf_guess=True,
    rhf_mom=True,
    orbital_coincidence='core',
    state_coincidence='full',
    )
# Out:
# #========================================================#
# #|          build the Lightspeed (pyTC) objecs          |#
# #========================================================#
# #========================================================#
# #|                      Geometry:                       |#
# #|                      QMMM = False                    |#
# #|                      -D3  = False                    |#
# #|                      ECP  = False                    |#
# #|                                                      |#
# #|            Molecule: twisted_fluoroethene            |#
# #|               Natom        =           6             |#
# #|               Charge       =       0.000             |#
# #|               Multiplicity =       1.000             |#
# #|                                                      |#
# #|                    Basis: 6-31gs                     |#
# #|                    nao     =    51                   |#
# #|                    ncart   =    51                   |#
# #|                    nprim   =    57                   |#
# #|                    nshell  =    24                   |#
# #|                    natom   =     6                   |#
# #|                    pure?   =    No                   |#
# #|                    max L   =     2                   |#
# #|                                                      |#
# #|                 Basis: cc-pvdz-minao                 |#
# #|                    nao     =    18                   |#
# #|                    ncart   =    18                   |#
# #|                    nprim   =    78                   |#
# #|                    nshell  =    12                   |#
# #|                    natom   =     6                   |#
# #|                    pure?   =   Yes                   |#
# #|                    max L   =     1                   |#
# #|                                                      |#
# #========================================================#
# ==> RHF <==
#
# External Environment:
#   Enuc =   6.8246411458977590E+01
#   Eext =   6.8246411458977590E+01
#
# SCF Iterations:
#
# Iter:                   Energy          dE          dG  Time[s]
#    0:  -1.7599180090279924E+02  -1.760E+02   1.245E+00    0.895
#    1:  -1.7690319850470294E+02  -9.114E-01   3.516E-02    0.070
#    2:  -1.7693984696942849E+02  -3.665E-02   1.845E-02    0.068
#    3:  -1.7694805805048333E+02  -8.211E-03   5.416E-03    0.062
#    4:  -1.7694885438088744E+02  -7.963E-04   1.160E-03    0.061
#    5:  -1.7694890470337140E+02  -5.032E-05   3.934E-04    0.056
#    6:  -1.7694891064690168E+02  -5.944E-06   1.160E-04    0.053
#    7:  -1.7694891137207946E+02  -7.252E-07   4.130E-05    0.050
#    8:  -1.7694891145963828E+02  -8.756E-08   8.695E-06    0.063
#    9:  -1.7694891146544279E+02  -5.805E-09   2.101E-06    0.045
#   10:  -1.7694891146574309E+02  -3.003E-10   6.545E-07    0.043
#
# SCF Converged
#
# SCF Energy =  -1.7694891146574309E+02
#
# SCF Internal Energy (E)     =  -1.7649324353178383E+02
# SCF Entropy Term (-T * S)   =  -4.5566793395925259E-01
# SCF Free Energy (E - T * S) =  -1.7694891146574309E+02
#
# ==> End RHF <==
#
# ==> CASCI <==
#
# External Environment:
#   Enuc =   6.8246411458977590E+01
#   Eext =   6.8246411458977590E+01
#
# Core Energy =  -175.66516750321773
#
# => S=0 States <=
#
# CASCI S=0 Energies:
#
#    I:                  Total E
#    0:  -1.7674088210471800E+02
#    1:  -1.7656769612747098E+02
#
# => End S=0 States <=
#
# ==> End CASCI <==

# %%
printcool("Build the pyGSM Level of Theory object (LOT)")
lot=PyTC.from_options(states=[(1,0),(1,1)],extra_kwargs={'psiw':psiw},fnm=filepath)
# Out:
# #========================================================#
# #|     Build the pyGSM Level of Theory object (LOT)     |#
# #========================================================#
#  initializing LOT from file

# %%
printcool("Build the pyGSM Potential Energy Surface Object (PES)")
pes = PES.from_options(lot=lot,ad_idx=0,multiplicity=1)
# Out:
# #===========================================================#
# #|  Build the pyGSM Potential Energy Surface Object (PES)  |#
# #===========================================================#

# %%
printcool("Build the pyGSM Molecule object \n with Translation and Rotation Internal Coordinates (TRIC)")
M = Molecule.from_options(fnm=filepath,PES=pes,coordinate_type="TRIC")
# Out:
# #================================================================#
# #|               Build the pyGSM Molecule object                |#
# #|   with Translation and Rotation Internal Coordinates (TRIC)  |#
# #================================================================#
#  reading cartesian coordinates from file
#  making primitives from options!
#  making primitive Hessian
#  forming Hessian in basis

# %%
from conjugate_gradient import conjugate_gradient
from _linesearch import backtrack
cg = conjugate_gradient.from_options(Linesearch=backtrack,DMAX=0.25)

# %%
geoms,energy = cg.optimize(M,M.energy,'UNCONSTRAINED',50)
# Out:
#  initial E 0.0000
#  On opt step 1
#  actual_step= 0.68
#  reducing step, new step = 0.25
#  Linesearch
#  Done linesearch
#  dEstep=-43.2588
#  Opt step: 1 E: -43.2588 gradrms: 0.16090 ss: 0.250 DMAX: 0.250
#  maximum displacement component 0.09 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 2
#  actual_step= 0.09
#  Linesearch
#  Done linesearch
#  dEstep=-3.8019
#  Opt step: 2 E: -47.0608 gradrms: 0.02128 ss: 0.090 DMAX: 0.250
#  maximum displacement component 0.03 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 3
#  actual_step= 0.08
#  Linesearch
#  Done linesearch
#  dEstep=-3.1905
#  Opt step: 3 E: -50.2512 gradrms: 0.01821 ss: 0.077 DMAX: 0.250
#  maximum displacement component 0.03 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 4
#  actual_step= 0.07
#  Linesearch
#  Done linesearch
#  dEstep=-2.8691
#  Opt step: 4 E: -53.1204 gradrms: 0.01669 ss: 0.071 DMAX: 0.250
#  maximum displacement component 0.03 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 5
#  actual_step= 0.07
#  Linesearch
#  Done linesearch
#  dEstep=-2.6335
#  Opt step: 5 E: -55.7538 gradrms: 0.01574 ss: 0.067 DMAX: 0.250
#  maximum displacement component 0.03 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 6
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-2.4517
#  Opt step: 6 E: -58.2055 gradrms: 0.01505 ss: 0.064 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 7
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-2.2935
#  Opt step: 7 E: -60.4990 gradrms: 0.01449 ss: 0.061 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 8
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-2.1556
#  Opt step: 8 E: -62.6547 gradrms: 0.01400 ss: 0.059 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 9
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-2.0309
#  Opt step: 9 E: -64.6856 gradrms: 0.01357 ss: 0.058 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 10
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-1.9172
#  Opt step: 10 E: -66.6027 gradrms: 0.01317 ss: 0.056 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 11
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.8124
#  Opt step: 11 E: -68.4152 gradrms: 0.01279 ss: 0.054 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 12
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.7149
#  Opt step: 12 E: -70.1300 gradrms: 0.01244 ss: 0.053 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 13
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.6239
#  Opt step: 13 E: -71.7540 gradrms: 0.01210 ss: 0.051 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 14
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.5386
#  Opt step: 14 E: -73.2925 gradrms: 0.01178 ss: 0.050 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 15
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.4582
#  Opt step: 15 E: -74.7508 gradrms: 0.01148 ss: 0.049 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 16
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.3823
#  Opt step: 16 E: -76.1331 gradrms: 0.01118 ss: 0.047 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 17
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.3106
#  Opt step: 17 E: -77.4437 gradrms: 0.01090 ss: 0.046 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 18
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-1.2425
#  Opt step: 18 E: -78.6862 gradrms: 0.01063 ss: 0.045 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 19
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-1.1778
#  Opt step: 19 E: -79.8640 gradrms: 0.01037 ss: 0.044 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 20
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-1.1163
#  Opt step: 20 E: -80.9804 gradrms: 0.01012 ss: 0.043 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 21
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-1.0575
#  Opt step: 21 E: -82.0378 gradrms: 0.00989 ss: 0.042 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 22
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-1.0015
#  Opt step: 22 E: -83.0393 gradrms: 0.00969 ss: 0.041 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 23
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.9471
#  Opt step: 23 E: -83.9864 gradrms: 0.00951 ss: 0.040 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 24
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.8956
#  Opt step: 24 E: -84.8821 gradrms: 0.00937 ss: 0.040 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 25
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.8432
#  Opt step: 25 E: -85.7253 gradrms: 0.00929 ss: 0.039 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 26
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.7953
#  Opt step: 26 E: -86.5206 gradrms: 0.00929 ss: 0.039 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 27
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.7396
#  Opt step: 27 E: -87.2602 gradrms: 0.00942 ss: 0.040 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 28
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.6942
#  Opt step: 28 E: -87.9543 gradrms: 0.00970 ss: 0.041 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 29
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.6204
#  Opt step: 29 E: -88.5747 gradrms: 0.01028 ss: 0.044 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 30
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-0.5800
#  Opt step: 30 E: -89.1546 gradrms: 0.01109 ss: 0.047 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 31
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-0.4432
#  Opt step: 31 E: -89.5978 gradrms: 0.01253 ss: 0.053 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 32
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-0.4326
#  Opt step: 32 E: -90.0304 gradrms: 0.01422 ss: 0.060 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 33
#  actual_step= 0.07
#  Linesearch
#  Done linesearch
#  dEstep=-0.0896
#  Opt step: 33 E: -90.1200 gradrms: 0.01716 ss: 0.073 DMAX: 0.250
#  maximum displacement component 0.03 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 34
#  actual_step= 0.08
#  Linesearch
#  Done linesearch
#  dEstep=-0.2516
#  Opt step: 34 E: -90.3716 gradrms: 0.02002 ss: 0.085 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 35
#  actual_step= 0.11
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.05
#  Done linesearch
#  dEstep=-1.4388
#  Opt step: 35 E: -91.8104 gradrms: 0.02524 ss: 0.054 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 36
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.4313
#  Opt step: 36 E: -92.2417 gradrms: 0.00866 ss: 0.037 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 37
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.3510
#  Opt step: 37 E: -92.5927 gradrms: 0.00971 ss: 0.041 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 38
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-0.3105
#  Opt step: 38 E: -92.9032 gradrms: 0.01111 ss: 0.047 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 39
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-0.1056
#  Opt step: 39 E: -93.0088 gradrms: 0.01356 ss: 0.058 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 40
#  actual_step= 0.07
#  Linesearch
#  Done linesearch
#  dEstep=-0.1148
#  Opt step: 40 E: -93.1236 gradrms: 0.01625 ss: 0.069 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 41
#  actual_step= 0.09
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.04
#  Done linesearch
#  dEstep=-1.0116
#  Opt step: 41 E: -94.1352 gradrms: 0.02104 ss: 0.045 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 42
#  actual_step= 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.3088
#  Opt step: 42 E: -94.4440 gradrms: 0.00733 ss: 0.031 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 43
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.2471
#  Opt step: 43 E: -94.6911 gradrms: 0.00832 ss: 0.035 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 44
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.2040
#  Opt step: 44 E: -94.8952 gradrms: 0.00970 ss: 0.041 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  On opt step 45
#  actual_step= 0.05
#  Linesearch
#  Done linesearch
#  dEstep=-0.0347
#  Opt step: 45 E: -94.9299 gradrms: 0.01210 ss: 0.051 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 46
#  actual_step= 0.06
#  Linesearch
#  Done linesearch
#  dEstep=-0.0064
#  Opt step: 46 E: -94.9363 gradrms: 0.01487 ss: 0.063 DMAX: 0.250
#  maximum displacement component 0.02 (au)
#  maximum gradient component 0.03 (au)
#
#  On opt step 47
#  actual_step= 0.08
#  Linesearch
#  [INFO] not satisfy sufficient decrease condition.
#  step 0.04
#  Done linesearch
#  dEstep=-0.8658
#  Opt step: 47 E: -95.8021 gradrms: 0.01974 ss: 0.042 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 48
#  actual_step= 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.2107
#  Opt step: 48 E: -96.0128 gradrms: 0.00663 ss: 0.028 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 49
#  actual_step= 0.03
#  Linesearch
#  Done linesearch
#  dEstep=-0.1518
#  Opt step: 49 E: -96.1646 gradrms: 0.00778 ss: 0.033 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.01 (au)
#
#  On opt step 50
#  actual_step= 0.04
#  Linesearch
#  Done linesearch
#  dEstep=-0.1071
#  Opt step: 50 E: -96.2717 gradrms: 0.00937 ss: 0.040 DMAX: 0.250
#  maximum displacement component 0.01 (au)
#  maximum gradient component 0.02 (au)
#
#  opt-summary
#  Opt step: 1 E: -43.2588 gradrms: 0.16090 ss: 0.250 DMAX: 0.250
#  Opt step: 2 E: -47.0608 gradrms: 0.02128 ss: 0.090 DMAX: 0.250
#  Opt step: 3 E: -50.2512 gradrms: 0.01821 ss: 0.077 DMAX: 0.250
#  Opt step: 4 E: -53.1204 gradrms: 0.01669 ss: 0.071 DMAX: 0.250
#  Opt step: 5 E: -55.7538 gradrms: 0.01574 ss: 0.067 DMAX: 0.250
#  Opt step: 6 E: -58.2055 gradrms: 0.01505 ss: 0.064 DMAX: 0.250
#  Opt step: 7 E: -60.4990 gradrms: 0.01449 ss: 0.061 DMAX: 0.250
#  Opt step: 8 E: -62.6547 gradrms: 0.01400 ss: 0.059 DMAX: 0.250
#  Opt step: 9 E: -64.6856 gradrms: 0.01357 ss: 0.058 DMAX: 0.250
#  Opt step: 10 E: -66.6027 gradrms: 0.01317 ss: 0.056 DMAX: 0.250
#  Opt step: 11 E: -68.4152 gradrms: 0.01279 ss: 0.054 DMAX: 0.250
#  Opt step: 12 E: -70.1300 gradrms: 0.01244 ss: 0.053 DMAX: 0.250
#  Opt step: 13 E: -71.7540 gradrms: 0.01210 ss: 0.051 DMAX: 0.250
#  Opt step: 14 E: -73.2925 gradrms: 0.01178 ss: 0.050 DMAX: 0.250
#  Opt step: 15 E: -74.7508 gradrms: 0.01148 ss: 0.049 DMAX: 0.250
#  Opt step: 16 E: -76.1331 gradrms: 0.01118 ss: 0.047 DMAX: 0.250
#  Opt step: 17 E: -77.4437 gradrms: 0.01090 ss: 0.046 DMAX: 0.250
#  Opt step: 18 E: -78.6862 gradrms: 0.01063 ss: 0.045 DMAX: 0.250
#  Opt step: 19 E: -79.8640 gradrms: 0.01037 ss: 0.044 DMAX: 0.250
#  Opt step: 20 E: -80.9804 gradrms: 0.01012 ss: 0.043 DMAX: 0.250
#  Opt step: 21 E: -82.0378 gradrms: 0.00989 ss: 0.042 DMAX: 0.250
#  Opt step: 22 E: -83.0393 gradrms: 0.00969 ss: 0.041 DMAX: 0.250
#  Opt step: 23 E: -83.9864 gradrms: 0.00951 ss: 0.040 DMAX: 0.250
#  Opt step: 24 E: -84.8821 gradrms: 0.00937 ss: 0.040 DMAX: 0.250
#  Opt step: 25 E: -85.7253 gradrms: 0.00929 ss: 0.039 DMAX: 0.250
#  Opt step: 26 E: -86.5206 gradrms: 0.00929 ss: 0.039 DMAX: 0.250
#  Opt step: 27 E: -87.2602 gradrms: 0.00942 ss: 0.040 DMAX: 0.250
#  Opt step: 28 E: -87.9543 gradrms: 0.00970 ss: 0.041 DMAX: 0.250
#  Opt step: 29 E: -88.5747 gradrms: 0.01028 ss: 0.044 DMAX: 0.250
#  Opt step: 30 E: -89.1546 gradrms: 0.01109 ss: 0.047 DMAX: 0.250
#  Opt step: 31 E: -89.5978 gradrms: 0.01253 ss: 0.053 DMAX: 0.250
#  Opt step: 32 E: -90.0304 gradrms: 0.01422 ss: 0.060 DMAX: 0.250
#  Opt step: 33 E: -90.1200 gradrms: 0.01716 ss: 0.073 DMAX: 0.250
#  Opt step: 34 E: -90.3716 gradrms: 0.02002 ss: 0.085 DMAX: 0.250
#  Opt step: 35 E: -91.8104 gradrms: 0.02524 ss: 0.054 DMAX: 0.250
#  Opt step: 36 E: -92.2417 gradrms: 0.00866 ss: 0.037 DMAX: 0.250
#  Opt step: 37 E: -92.5927 gradrms: 0.00971 ss: 0.041 DMAX: 0.250
#  Opt step: 38 E: -92.9032 gradrms: 0.01111 ss: 0.047 DMAX: 0.250
#  Opt step: 39 E: -93.0088 gradrms: 0.01356 ss: 0.058 DMAX: 0.250
#  Opt step: 40 E: -93.1236 gradrms: 0.01625 ss: 0.069 DMAX: 0.250
#  Opt step: 41 E: -94.1352 gradrms: 0.02104 ss: 0.045 DMAX: 0.250
#  Opt step: 42 E: -94.4440 gradrms: 0.00733 ss: 0.031 DMAX: 0.250
#  Opt step: 43 E: -94.6911 gradrms: 0.00832 ss: 0.035 DMAX: 0.250
#  Opt step: 44 E: -94.8952 gradrms: 0.00970 ss: 0.041 DMAX: 0.250
#  Opt step: 45 E: -94.9299 gradrms: 0.01210 ss: 0.051 DMAX: 0.250
#  Opt step: 46 E: -94.9363 gradrms: 0.01487 ss: 0.063 DMAX: 0.250
#  Opt step: 47 E: -95.8021 gradrms: 0.01974 ss: 0.042 DMAX: 0.250
#  Opt step: 48 E: -96.0128 gradrms: 0.00663 ss: 0.028 DMAX: 0.250
#  Opt step: 49 E: -96.1646 gradrms: 0.00778 ss: 0.033 DMAX: 0.250
#  Opt step: 50 E: -96.2717 gradrms: 0.00937 ss: 0.040 DMAX: 0.250

# %%
manage_xyz.write_xyzs_w_comments('opt.xyz',geoms,energy,scale=1.)
